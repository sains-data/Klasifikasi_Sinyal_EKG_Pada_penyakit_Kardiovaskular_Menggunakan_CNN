# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Split Data Train dan Validasi

# %%
# Path dataset asli
data_dir = "/content/drive/MyDrive/Tubes DL"
train_dir = "/content/drive/MyDrive/dataset_tubes_split/train"
valid_dir = "/content/drive/MyDrive/dataset_tubes_split/valid"
test_dir = "/content/drive/MyDrive/dataset_tubes_split/test"

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Path dataset asli
data_dir = "/content/drive/MyDrive/Tubes DL"
train_dir = "/content/drive/MyDrive/dataset_tubes_split/train"
valid_dir = "/content/drive/MyDrive/dataset_tubes_split/valid"
test_dir = "/content/drive/MyDrive/dataset_tubes_split/test"

# Membuat folder train, valid, dan test jika belum ada
os.makedirs(train_dir, exist_ok=True)
os.makedirs(valid_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Membaca semua subfolder (misalnya 'normal', 'abnormal')
categories = os.listdir(data_dir)

# Memproses setiap kategori (subfolder)
for category in categories:
    category_path = os.path.join(data_dir, category)

    # Cek jika itu adalah direktori (bukan file)
    if os.path.isdir(category_path):
        # Membaca semua gambar dalam kategori
        all_images = os.listdir(category_path)

        # Membagi data menjadi train (70%) dan sisanya (30%)
        train_images, temp_images = train_test_split(all_images, test_size=0.3, random_state=42)

        # Membagi sisanya (30%) menjadi valid (15%) dan test (15%)
        valid_images, test_images = train_test_split(temp_images, test_size=0.5, random_state=42)

        # Membuat subfolder untuk kategori di dalam folder train, valid, dan test
        os.makedirs(os.path.join(train_dir, category), exist_ok=True)
        os.makedirs(os.path.join(valid_dir, category), exist_ok=True)
        os.makedirs(os.path.join(test_dir, category), exist_ok=True)

        # Menyalin file ke folder train
        for img in train_images:
            shutil.copy(os.path.join(category_path, img), os.path.join(train_dir, category, img))

        # Menyalin file ke folder valid
        for img in valid_images:
            shutil.copy(os.path.join(category_path, img), os.path.join(valid_dir, category, img))

        # Menyalin file ke folder test
        for img in test_images:
            shutil.copy(os.path.join(category_path, img), os.path.join(test_dir, category, img))

        print(f"Folder '{category}' berhasil dibagi menjadi train, valid, dan test.")
# Out:
# Folder 'abnormal' berhasil dibagi menjadi train, valid, dan test.
# Folder 'normal' berhasil dibagi menjadi train, valid, dan test.

# %%
import os
def count_files(directory):
    total = 0
    for root, dirs, files in os.walk(directory):
        total += len(files)
    return total

print(f"Train Normal: {count_files(os.path.join(train_dir, 'normal'))}")
print(f"Train Abnormal: {count_files(os.path.join(train_dir, 'abnormal'))}")
print(f"Valid Normal: {count_files(os.path.join(valid_dir, 'normal'))}")
print(f"Valid Abnormal: {count_files(os.path.join(valid_dir, 'abnormal'))}")
print(f"Test Normal: {count_files(os.path.join(test_dir, 'normal'))}")
print(f"Test Abnormal: {count_files(os.path.join(test_dir, 'abnormal'))}")
# Out:
# Train Normal: 163
# Train Abnormal: 140
# Valid Normal: 35
# Valid Abnormal: 30
# Test Normal: 35
# Test Abnormal: 30

# %% [markdown]
# ### Import Libraries

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize

# %% [markdown]
# ### Setting dataset Path & Hyperparameters

# %%
# Ukuran gambar dan batch size
img_height, img_width = 224, 224  # Meningkatkan ukuran gambar
batch_size = 32  # Mengurangi batch size untuk stabilitas pelatihan

# %% [markdown]
# ### Data Preprocessing & Augmentasi

# %%
# ImageDataGenerator untuk training dan validasi
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,  # Mengurangi rotation range
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,  # Mengurangi shear range
    zoom_range=0.1,   # Mengurangi zoom range
    horizontal_flip=True
)

valid_datagen = ImageDataGenerator(rescale=1./255)

# Data training
train_data = train_datagen.flow_from_directory(
    directory=train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb',  # Menggunakan RGB
    class_mode='binary'
)

# Data validasi
val_data = valid_datagen.flow_from_directory(
    directory=valid_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    color_mode='rgb',  # Menggunakan RGB
    class_mode='binary'
)
# Out:
# Found 303 images belonging to 2 classes.
# Found 65 images belonging to 2 classes.

# %% [markdown]
# # **Model 1**
#
# Learning Rate = 1e-4, Droput = 0.3, Frozen Layers = Semua kecuali Layer 2, Epoch = 50, dan Optimizer = Adam

# %% [markdown]
# ### Membangun Model

# %%
# Menggunakan VGG16 sebagai base model
base_model = tf.keras.applications.VGG16(
    weights='imagenet',  # Pre-trained weights dari ImageNet
    include_top=False,   # Menghapus fully connected layer terakhir
    input_shape=(img_height, img_width, 3)  # Input shape untuk RGB
)

# Membekukan beberapa layer terakhir dari base model untuk fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-2]:  # Membekukan lebih sedikit layer
    layer.trainable = False

# Menambahkan fully connected layers di atas base model
model = models.Sequential([
    base_model,
    layers.Flatten(),  # Flatten output convolusi
    layers.Dense(128, activation='relu'),  # Fully connected layer
    layers.Dropout(0.3),  # Mengurangi dropout
    layers.Dense(1, activation='sigmoid')  # Output layer untuk binary classification
])

# Kompilasi model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),  # Learning rate yang sedikit lebih tinggi
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,926,209 (68.38 MB)
#  Trainable params: 5,571,329 (21.25 MB)
#  Non-trainable params: 12,354,880 (47.13 MB)

# %% [markdown]
# ### Call & Training

# %%
# Callback EarlyStopping untuk menghentikan pelatihan jika tidak ada perbaikan
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Training model dengan data augmentation tanpa workers
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=50,  # Meningkatkan jumlah epochs
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.5617 - loss: 0.6923 - val_accuracy: 0.7077 - val_loss: 0.5524
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 55s 666ms/step - accuracy: 0.7203 - loss: 0.5509 - val_accuracy: 0.6615 - val_loss: 0.5196
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.7606 - loss: 0.4769 - val_accuracy: 0.6769 - val_loss: 0.5117
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 454ms/step - accuracy: 0.7933 - loss: 0.4328 - val_accuracy: 0.8000 - val_loss: 0.4112
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 614ms/step - accuracy: 0.8306 - loss: 0.3289 - val_accuracy: 0.9538 - val_loss: 0.2370
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 627ms/step - accuracy: 0.9085 - loss: 0.2334 - val_accuracy: 0.9231 - val_loss: 0.1948
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 507ms/step - accuracy: 0.9283 - loss: 0.1977 - val_accuracy: 0.8615 - val_loss: 0.2853
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 447ms/step - accuracy: 0.8487 - loss: 0.2951 - val_accuracy: 0.9538 - val_loss: 0.1956
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 517ms/step - accuracy: 0.9066 - loss: 0.2109 - val_accuracy: 0.9385 - val_loss: 0.1609
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 524ms/step - accuracy: 0.9313 - loss: 0.1618 - val_accuracy: 0.9538 - val_loss: 0.1595
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 636ms/step - accuracy: 0.9397 - loss: 0.1674 - val_accuracy: 0.9538 - val_loss: 0.1311
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 576ms/step - accuracy: 0.9287 - loss: 0.1837 - val_accuracy: 0.9538 - val_loss: 0.1257
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 915ms/step - accuracy: 0.9278 - loss: 0.1547 - val_accuracy: 0.9538 - val_loss: 0.1182
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 625ms/step - accuracy: 0.9524 - loss: 0.1343 - val_accuracy: 0.9538 - val_loss: 0.0995
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 517ms/step - accuracy: 0.9607 - loss: 0.1330 - val_accuracy: 0.9538 - val_loss: 0.1286
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 661ms/step - accuracy: 0.9411 - loss: 0.1280 - val_accuracy: 0.9538 - val_loss: 0.0979
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 615ms/step - accuracy: 0.9504 - loss: 0.1232 - val_accuracy: 0.9692 - val_loss: 0.0850
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 530ms/step - accuracy: 0.9590 - loss: 0.0985 - val_accuracy: 0.9692 - val_loss: 0.0641
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 630ms/step - accuracy: 0.9488 - loss: 0.1389 - val_accuracy: 0.9846 - val_loss: 0.0653
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 633ms/step - accuracy: 0.9689 - loss: 0.1002 - val_accuracy: 0.9692 - val_loss: 0.0780
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 13s 609ms/step - accuracy: 0.9610 - loss: 0.1012 - val_accuracy: 0.9846 - val_loss: 0.0727
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 457ms/step - accuracy: 0.9324 - loss: 0.1625 - val_accuracy: 0.9846 - val_loss: 0.0927
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.9266 - loss: 0.1784 - val_accuracy: 0.9538 - val_loss: 0.0970

# %% [markdown]
# ### Plot Hitory Training

# %%
# Visualisasi akurasi dan loss selama pelatihan
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluasi Model Data Validasi

# %%
# Evaluasi model pada data validasi
val_loss, val_acc = model.evaluate(val_data)
print(f"Validation Accuracy: {val_acc:.2f}")
print(f"Validation Loss: {val_loss:.2f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 580ms/step - accuracy: 0.9768 - loss: 0.0549
# Validation Accuracy: 0.97
# Validation Loss: 0.06

# %% [markdown]
# ### Model Evaluasi Pada Data Test

# %%
# Menyiapkan data uji dengan rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# Memuat data uji
test_data = test_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(img_height, img_width),  # Ukuran gambar yang sama dengan yang digunakan untuk pelatihan
    batch_size=batch_size,
    color_mode='rgb',  # Menggunakan mode warna RGB
    class_mode='binary',  # Untuk klasifikasi biner
    shuffle=False  # Jangan acak data agar urutannya tetap
)

# Prediksi model pada data uji
predictions = model.predict(test_data, verbose=1)

# Mengonversi prediksi ke label biner (0 atau 1) dengan threshold 0.5
predicted_labels = (predictions > 0.5).astype("int32")

# Mengambil label asli dari data uji
true_labels = test_data.classes
# Out:
# Found 65 images belonging to 2 classes.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 432ms/step

# %% [markdown]
# ### Confusion Matrix & Klafikasi Report

# %%
# Menghitung matriks kebingunguan
cm = confusion_matrix(true_labels, predicted_labels)

# Visualisasi matriks kebingunguan
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_data.class_indices.keys(),
            yticklabels=test_data.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Menampilkan laporan klasifikasi
print("Classification Report:\n", classification_report(true_labels, predicted_labels))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89        30
#            1       0.85      1.00      0.92        35
#
#     accuracy                           0.91        65
#    macro avg       0.93      0.90      0.90        65
# weighted avg       0.92      0.91      0.91        65

# %% [markdown]
# ### Evaluasi Model dengan ROC AUC

# %%
# Menghitung ROC AUC Score
# Prediksi probabilitas untuk kelas positif (label 1)
predicted_probs = model.predict(test_data, verbose=1)

# Menggunakan label biner untuk ROC AUC
# Jika dataset adalah binary, kita cukup menggunakan predicted_probs untuk kelas 1
roc_auc = roc_auc_score(true_labels, predicted_probs)

print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 497ms/step
# ROC AUC Score: 0.9857

# %% [markdown]
# ### Plot Kurva ROC

# %%
# Menghitung ROC curve
fpr, tpr, thresholds = roc_curve(true_labels, predicted_probs)

# Visualisasi ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Line diagonal
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Menampilkan hasil prediksi dan label aktual
print("\nPredictions vs Actual Labels:")
for i in range(len(test_data.filepaths)):
    actual_label = test_data.classes[i]  # Label asli
    predicted_label = predicted_labels[i][0]  # Prediksi model
    print(f"File: {test_data.filepaths[i]} | Predicted: {predicted_label} | Actual: {actual_label}")

# Mapping numerik ke nama kelas
class_indices = {v: k for k, v in test_data.class_indices.items()}
print("\nClass Mapping:", class_indices)
# Out:
# Predictions vs Actual Labels:
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(10).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(104).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(121).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(125).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(134).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(142).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(145).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(146).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(155).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(156).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(158).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(17).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(170).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(171).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(185).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(186).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(191).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(199).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(22).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(27).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(29).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(31).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(45).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(46).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(51).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(53).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(60).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(67).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(89).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(9).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(106).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(107).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(110).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(12).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(130).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(131).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(138).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(139).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(140).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(150).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(154).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(162).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(170).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(173).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(179).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(192).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(196).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(20).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(201).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(203).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(207).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(219).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(221).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(223).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(30).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(33).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(36).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(44).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(50).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(53).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(59).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(61).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(63).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(89).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(91).jpg | Predicted: 1 | Actual: 1
#
# Class Mapping: {0: 'abnormal', 1: 'normal'}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Mapping numerik ke nama kelas
class_indices = {v: k for k, v in test_data.class_indices.items()}

# List untuk menyimpan indeks gambar berdasarkan kelas
normal_indices = []
abnormal_indices = []

# Cari indeks untuk kelas normal dan abnormal
for i in range(len(test_data.filepaths)):
    actual_label = test_data.classes[i]  # Ambil label aktual
    if class_indices[actual_label] == "normal":
        normal_indices.append(i)
    elif class_indices[actual_label] == "abnormal":
        abnormal_indices.append(i)

# Ambil 5 indeks pertama dari masing-masing kelas
num_samples = 5
selected_indices = normal_indices[:num_samples] + abnormal_indices[:num_samples]

# Plot gambar
fig, axes = plt.subplots(2, num_samples, figsize=(15, 6))  # 2 baris, 5 kolom
fig.suptitle("Normal and Abnormal Samples", fontsize=16)

for i, ax in enumerate(axes.flat):
    if i >= len(selected_indices):
        break

    index = selected_indices[i]
    filepath = test_data.filepaths[index]
    actual_label = class_indices[test_data.classes[index]]
    predicted_label = class_indices[predicted_labels[index][0]]

    # Load gambar
    img = plt.imread(filepath)

    # Tampilkan gambar di subplot
    ax.imshow(img)
    ax.axis('off')

    # Tampilkan prediksi dan label aktual
    ax.set_title(
        f"Predicted: {predicted_label}\nActual: {actual_label}",
        fontsize=10
    )

plt.tight_layout(rect=[0, 0, 1, 0.9])  # Tambahkan ruang untuk judul
plt.show()

# %% [markdown]
# # **Model 2**
#
# Learning Rate = 1e-3, Droput = 0.5, Frozen Layers = Semua kecuali Layer 5, Batch Size = 64, Epoch = 100, dan Optimizer = Adam

# %% [markdown]
# ### Membangun Model

# %%
# Menggunakan VGG16 sebagai base model
base_model_2 = tf.keras.applications.VGG16(
    weights='imagenet',  # Pre-trained weights dari ImageNet
    include_top=False,   # Menghapus fully connected layer terakhir
    input_shape=(img_height, img_width, 3)  # Input shape untuk RGB
)

# Membekukan beberapa layer terakhir dari base model untuk fine-tuning
base_model_2.trainable = True
for layer in base_model_2.layers[:-5]:  # Membekukan lebih banyak layer
    layer.trainable = False

# Menambahkan fully connected layers di atas base model
model_2 = models.Sequential([
    base_model_2,
    layers.Flatten(),  # Flatten output convolusi
    layers.Dense(128, activation='relu'),  # Fully connected layer
    layers.Dropout(0.5),  # Ubah dropout menjadi lebih tinggi
    layers.Dense(1, activation='sigmoid')  # Output layer untuk binary classification
])

# Kompilasi model
model_2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model_2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,926,209 (68.38 MB)
#  Trainable params: 10,290,945 (39.26 MB)
#  Non-trainable params: 7,635,264 (29.13 MB)

# %% [markdown]
# ### Call & Training

# %%
# Callback EarlyStopping untuk menghentikan pelatihan jika tidak ada perbaikan
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Training model dengan data augmentation tanpa workers
history_2 = model_2.fit(
    train_data,
    validation_data=val_data,
    epochs=100,
    batch_size=64,  # Coba ukuran batch lebih besar
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 84s 4s/step - accuracy: 0.5022 - loss: 1.2522 - val_accuracy: 0.4615 - val_loss: 0.6922
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 576ms/step - accuracy: 0.4890 - loss: 0.8851 - val_accuracy: 0.5385 - val_loss: 0.6921
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 551ms/step - accuracy: 0.5369 - loss: 0.6936 - val_accuracy: 0.5385 - val_loss: 0.6928
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 568ms/step - accuracy: 0.5458 - loss: 0.6927 - val_accuracy: 0.5385 - val_loss: 0.6926
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 591ms/step - accuracy: 0.5480 - loss: 0.6922 - val_accuracy: 0.5385 - val_loss: 0.6924
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 460ms/step - accuracy: 0.5346 - loss: 0.6925 - val_accuracy: 0.5385 - val_loss: 0.6921
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 518ms/step - accuracy: 0.5149 - loss: 0.6927 - val_accuracy: 0.5385 - val_loss: 0.6919
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 673ms/step - accuracy: 0.5175 - loss: 0.6925 - val_accuracy: 0.5385 - val_loss: 0.6917
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 571ms/step - accuracy: 0.5373 - loss: 0.6916 - val_accuracy: 0.5385 - val_loss: 0.6915
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 538ms/step - accuracy: 0.5397 - loss: 0.6915 - val_accuracy: 0.5385 - val_loss: 0.6913
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 667ms/step - accuracy: 0.5626 - loss: 0.6901 - val_accuracy: 0.5385 - val_loss: 0.6912
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 635ms/step - accuracy: 0.5399 - loss: 0.6909 - val_accuracy: 0.5385 - val_loss: 0.6911
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 612ms/step - accuracy: 0.5099 - loss: 0.6928 - val_accuracy: 0.5385 - val_loss: 0.6910
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 597ms/step - accuracy: 0.4880 - loss: 0.6947 - val_accuracy: 0.5385 - val_loss: 0.6910
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 555ms/step - accuracy: 0.5569 - loss: 0.6892 - val_accuracy: 0.5385 - val_loss: 0.6909
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 686ms/step - accuracy: 0.5520 - loss: 0.6899 - val_accuracy: 0.5385 - val_loss: 0.6907
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 551ms/step - accuracy: 0.5575 - loss: 0.6889 - val_accuracy: 0.5385 - val_loss: 0.6907
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 497ms/step - accuracy: 0.5233 - loss: 0.6921 - val_accuracy: 0.5385 - val_loss: 0.6906
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 693ms/step - accuracy: 0.5372 - loss: 0.6910 - val_accuracy: 0.5385 - val_loss: 0.6906
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 568ms/step - accuracy: 0.4798 - loss: 0.6970 - val_accuracy: 0.5385 - val_loss: 0.6906
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 556ms/step - accuracy: 0.5510 - loss: 0.6898 - val_accuracy: 0.5385 - val_loss: 0.6906
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 580ms/step - accuracy: 0.5485 - loss: 0.6893 - val_accuracy: 0.5385 - val_loss: 0.6905
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 666ms/step - accuracy: 0.5465 - loss: 0.6900 - val_accuracy: 0.5385 - val_loss: 0.6918
# Epoch 24/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 18s 611ms/step - accuracy: 0.4963 - loss: 0.7072 - val_accuracy: 0.5385 - val_loss: 0.6904
# Epoch 25/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 536ms/step - accuracy: 0.5421 - loss: 0.6913 - val_accuracy: 0.5385 - val_loss: 0.6904
# Epoch 26/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 550ms/step - accuracy: 0.5515 - loss: 0.6879 - val_accuracy: 0.5385 - val_loss: 0.6903
# Epoch 27/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 536ms/step - accuracy: 0.5217 - loss: 0.6931 - val_accuracy: 0.5385 - val_loss: 0.6903
# Epoch 28/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 634ms/step - accuracy: 0.5555 - loss: 0.6877 - val_accuracy: 0.5385 - val_loss: 0.6902
# Epoch 29/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 14s 530ms/step - accuracy: 0.5560 - loss: 0.6873 - val_accuracy: 0.5385 - val_loss: 0.6902
# Epoch 30/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 661ms/step - accuracy: 0.5789 - loss: 0.6838 - val_accuracy: 0.5385 - val_loss: 0.6902
# Epoch 31/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 531ms/step - accuracy: 0.5330 - loss: 0.6915 - val_accuracy: 0.5385 - val_loss: 0.6902
# Epoch 32/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 655ms/step - accuracy: 0.5213 - loss: 0.6929 - val_accuracy: 0.5385 - val_loss: 0.6902
# Epoch 33/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 539ms/step - accuracy: 0.5400 - loss: 0.6889 - val_accuracy: 0.5385 - val_loss: 0.6902
# Epoch 34/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 624ms/step - accuracy: 0.5680 - loss: 0.6869 - val_accuracy: 0.5385 - val_loss: 0.6902
# Epoch 35/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 521ms/step - accuracy: 0.5699 - loss: 0.6856 - val_accuracy: 0.5385 - val_loss: 0.6902

# %% [markdown]
# ### Plot Hitory Training

# %%
# Visualisasi akurasi dan loss selama pelatihan
plt.plot(history_2.history['accuracy'], label='Train Accuracy')
plt.plot(history_2.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_2.history['loss'], label='Train Loss')
plt.plot(history_2.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluasi Model Data Validasi

# %%
# Evaluasi model pada data validasi
val_loss, val_acc = model_2.evaluate(val_data)
print(f"Validation Accuracy: {val_acc:.2f}")
print(f"Validation Loss: {val_loss:.2f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 390ms/step - accuracy: 0.5231 - loss: 0.6924
# Validation Accuracy: 0.54
# Validation Loss: 0.69

# %% [markdown]
# ### Model Evaluasi Pada Data Test

# %%
# Menyiapkan data uji dengan rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# Memuat data uji
test_data = test_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(img_height, img_width),  # Ukuran gambar yang sama dengan yang digunakan untuk pelatihan
    batch_size=batch_size,
    color_mode='rgb',  # Menggunakan mode warna RGB
    class_mode='binary',  # Untuk klasifikasi biner
    shuffle=False  # Jangan acak data agar urutannya tetap
)

# Prediksi model pada data uji
predictions = model_2.predict(test_data, verbose=1)

# Mengonversi prediksi ke label biner (0 atau 1) dengan threshold 0.5
predicted_labels = (predictions > 0.5).astype("int32")

# Mengambil label asli dari data uji
true_labels = test_data.classes
# Out:
# Found 65 images belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 412ms/step

# %% [markdown]
# ### Confusion Matrix & Klafikasi Report

# %%
# Menghitung matriks kebingunguan
cm = confusion_matrix(true_labels, predicted_labels)

# Visualisasi matriks kebingunguan
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_data.class_indices.keys(),
            yticklabels=test_data.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Menampilkan laporan klasifikasi
print("Classification Report:\n", classification_report(true_labels, predicted_labels))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        30
#            1       0.54      1.00      0.70        35
#
#     accuracy                           0.54        65
#    macro avg       0.27      0.50      0.35        65
# weighted avg       0.29      0.54      0.38        65
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Evaluasi Model dengan ROC AUC

# %%
# Menghitung ROC AUC Score
# Prediksi probabilitas untuk kelas positif (label 1)
predicted_probs = model_2.predict(test_data, verbose=1)

# Menggunakan label biner untuk ROC AUC
# Jika dataset adalah binary, kita cukup menggunakan predicted_probs untuk kelas 1
roc_auc = roc_auc_score(true_labels, predicted_probs)

print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 426ms/step
# ROC AUC Score: 0.5000

# %% [markdown]
# ### Plot Kurva ROC

# %%
# Menghitung ROC curve
fpr, tpr, thresholds = roc_curve(true_labels, predicted_probs)

# Visualisasi ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Line diagonal
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Menampilkan hasil prediksi dan label aktual
print("\nPredictions vs Actual Labels:")
for i in range(len(test_data.filepaths)):
    actual_label = test_data.classes[i]  # Label asli
    predicted_label = predicted_labels[i][0]  # Prediksi model
    print(f"File: {test_data.filepaths[i]} | Predicted: {predicted_label} | Actual: {actual_label}")

# Mapping numerik ke nama kelas
class_indices = {v: k for k, v in test_data.class_indices.items()}
print("\nClass Mapping:", class_indices)
# Out:
# Predictions vs Actual Labels:
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(10).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(104).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(121).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(125).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(134).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(142).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(145).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(146).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(155).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(156).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(158).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(17).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(170).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(171).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(185).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(186).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(191).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(199).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(22).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(27).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(29).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(31).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(45).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(46).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(51).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(53).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(60).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(67).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(89).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(9).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(106).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(107).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(110).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(12).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(130).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(131).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(138).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(139).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(140).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(150).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(154).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(162).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(170).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(173).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(179).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(192).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(196).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(20).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(201).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(203).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(207).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(219).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(221).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(223).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(30).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(33).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(36).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(44).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(50).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(53).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(59).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(61).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(63).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(89).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(91).jpg | Predicted: 1 | Actual: 1
#
# Class Mapping: {0: 'abnormal', 1: 'normal'}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Mapping numerik ke nama kelas
class_indices = {v: k for k, v in test_data.class_indices.items()}

# List untuk menyimpan indeks gambar berdasarkan kelas
normal_indices = []
abnormal_indices = []

# Cari indeks untuk kelas normal dan abnormal
for i in range(len(test_data.filepaths)):
    actual_label = test_data.classes[i]  # Ambil label aktual
    if class_indices[actual_label] == "normal":
        normal_indices.append(i)
    elif class_indices[actual_label] == "abnormal":
        abnormal_indices.append(i)

# Ambil 5 indeks pertama dari masing-masing kelas
num_samples = 5
selected_indices = normal_indices[:num_samples] + abnormal_indices[:num_samples]

# Plot gambar
fig, axes = plt.subplots(2, num_samples, figsize=(15, 6))  # 2 baris, 5 kolom
fig.suptitle("Normal and Abnormal Samples", fontsize=16)

for i, ax in enumerate(axes.flat):
    if i >= len(selected_indices):
        break

    index = selected_indices[i]
    filepath = test_data.filepaths[index]
    actual_label = class_indices[test_data.classes[index]]
    predicted_label = class_indices[predicted_labels[index][0]]

    # Load gambar
    img = plt.imread(filepath)

    # Tampilkan gambar di subplot
    ax.imshow(img)
    ax.axis('off')

    # Tampilkan prediksi dan label aktual
    ax.set_title(
        f"Predicted: {predicted_label}\nActual: {actual_label}",
        fontsize=10
    )

plt.tight_layout(rect=[0, 0, 1, 0.9])  # Tambahkan ruang untuk judul
plt.show()

# %% [markdown]
# # **Model 3**
#
# Learning Rate = 1e-4, Droput = 0.2, Frozen Layers = Semua kecuali Layer 10, Batch Size = 16, Epoch = 75, dan Optimizer = SGD (momentum=0.9)

# %% [markdown]
# ### Membangun Model

# %%
# Menggunakan VGG16 sebagai base model
base_model_3 = tf.keras.applications.VGG16(
    weights='imagenet',  # Pre-trained weights dari ImageNet
    include_top=False,   # Menghapus fully connected layer terakhir
    input_shape=(img_height, img_width, 3)  # Input shape untuk RGB
)

# Membekukan beberapa layer terakhir dari base model untuk fine-tuning
base_model_3.trainable = True
for layer in base_model_3.layers[:-10]:  # Membekukan semua layer kecuali 10
    layer.trainable = False

# Menambahkan fully connected layers di atas base model
model_3 = models.Sequential([
    base_model_3,
    layers.Flatten(),  # Flatten output convolusi
    layers.Dense(128, activation='relu'),  # Fully connected layer
    layers.Dropout(0.2),  # Mengurangi dropout
    layers.Dense(1, activation='sigmoid')  # Output layer untuk binary classification
])

# Kompilasi model
model_3.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=1e-3, momentum=0.9),  # Learning rate yang sedikit lebih tinggi
              loss='binary_crossentropy',
              metrics=['accuracy'])
model_3.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       3,211,392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │             129 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,926,209 (68.38 MB)
#  Trainable params: 16,780,801 (64.01 MB)
#  Non-trainable params: 1,145,408 (4.37 MB)

# %% [markdown]
# ### Call & Training

# %%
# Callback EarlyStopping untuk menghentikan pelatihan jika tidak ada perbaikan
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Training model dengan data augmentation tanpa workers
history_3 = model_3.fit(
    train_data,
    validation_data=val_data,
    epochs=75,
    batch_size=16,  # Coba ukuran batch lebih besar
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.5307 - loss: 0.8093 - val_accuracy: 0.5385 - val_loss: 0.7973
# Epoch 2/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 617ms/step - accuracy: 0.5304 - loss: 0.7827 - val_accuracy: 0.5385 - val_loss: 0.6930
# Epoch 3/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 829ms/step - accuracy: 0.5789 - loss: 0.6898 - val_accuracy: 0.4615 - val_loss: 0.6990
# Epoch 4/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 596ms/step - accuracy: 0.5214 - loss: 0.6879 - val_accuracy: 0.5846 - val_loss: 0.6539
# Epoch 5/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 763ms/step - accuracy: 0.6279 - loss: 0.6580 - val_accuracy: 0.8615 - val_loss: 0.5788
# Epoch 6/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 22s 789ms/step - accuracy: 0.7049 - loss: 0.5978 - val_accuracy: 0.4615 - val_loss: 0.9487
# Epoch 7/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 744ms/step - accuracy: 0.7740 - loss: 0.5314 - val_accuracy: 0.9231 - val_loss: 0.2393
# Epoch 8/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 770ms/step - accuracy: 0.7998 - loss: 0.4824 - val_accuracy: 0.6000 - val_loss: 0.5216
# Epoch 9/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 738ms/step - accuracy: 0.7561 - loss: 0.5156 - val_accuracy: 0.8462 - val_loss: 0.3735
# Epoch 10/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 688ms/step - accuracy: 0.8134 - loss: 0.3975 - val_accuracy: 0.9231 - val_loss: 0.2454
# Epoch 11/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 727ms/step - accuracy: 0.8953 - loss: 0.2889 - val_accuracy: 0.9692 - val_loss: 0.1141
# Epoch 12/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 15s 725ms/step - accuracy: 0.9301 - loss: 0.1721 - val_accuracy: 0.9538 - val_loss: 0.1188
# Epoch 13/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 641ms/step - accuracy: 0.9204 - loss: 0.2100 - val_accuracy: 0.8308 - val_loss: 0.4682
# Epoch 14/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 689ms/step - accuracy: 0.8752 - loss: 0.3278 - val_accuracy: 0.8615 - val_loss: 0.3134
# Epoch 15/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 729ms/step - accuracy: 0.8675 - loss: 0.3070 - val_accuracy: 0.9692 - val_loss: 0.0971
# Epoch 16/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 21s 571ms/step - accuracy: 0.9095 - loss: 0.2198 - val_accuracy: 0.9385 - val_loss: 0.2048
# Epoch 17/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 772ms/step - accuracy: 0.9110 - loss: 0.2080 - val_accuracy: 0.9538 - val_loss: 0.1128
# Epoch 18/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 20s 639ms/step - accuracy: 0.9615 - loss: 0.1174 - val_accuracy: 0.9538 - val_loss: 0.1203
# Epoch 19/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 680ms/step - accuracy: 0.9755 - loss: 0.0776 - val_accuracy: 0.9077 - val_loss: 0.2397
# Epoch 20/75
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 16s 739ms/step - accuracy: 0.9174 - loss: 0.2742 - val_accuracy: 0.9538 - val_loss: 0.1027

# %% [markdown]
# ### Plot Hitory Training

# %%
# Visualisasi akurasi dan loss selama pelatihan
plt.plot(history_3.history['accuracy'], label='Train Accuracy')
plt.plot(history_3.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history_3.history['loss'], label='Train Loss')
plt.plot(history_3.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluasi Model Data Validasi

# %%
# Evaluasi model pada data validasi
val_loss, val_acc = model_3.evaluate(val_data)
print(f"Validation Accuracy: {val_acc:.2f}")
print(f"Validation Loss: {val_loss:.2f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 464ms/step - accuracy: 0.9690 - loss: 0.0967
# Validation Accuracy: 0.97
# Validation Loss: 0.10

# %% [markdown]
# ### Model Evaluasi Pada Data Test

# %%
# Menyiapkan data uji dengan rescaling
test_datagen = ImageDataGenerator(rescale=1./255)

# Memuat data uji
test_data = test_datagen.flow_from_directory(
    directory=test_dir,
    target_size=(img_height, img_width),  # Ukuran gambar yang sama dengan yang digunakan untuk pelatihan
    batch_size=batch_size,
    color_mode='rgb',  # Menggunakan mode warna RGB
    class_mode='binary',  # Untuk klasifikasi biner
    shuffle=False  # Jangan acak data agar urutannya tetap
)

# Prediksi model pada data uji
predictions = model_3.predict(test_data, verbose=1)

# Mengonversi prediksi ke label biner (0 atau 1) dengan threshold 0.5
predicted_labels = (predictions > 0.5).astype("int32")

# Mengambil label asli dari data uji
true_labels = test_data.classes
# Out:
# Found 65 images belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 377ms/step

# %% [markdown]
# ### Confusion Matrix & Klafikasi Report

# %%
# Menghitung matriks kebingunguan
cm = confusion_matrix(true_labels, predicted_labels)

# Visualisasi matriks kebingunguan
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=test_data.class_indices.keys(),
            yticklabels=test_data.class_indices.keys())
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Menampilkan laporan klasifikasi
print("Classification Report:\n", classification_report(true_labels, predicted_labels))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        30
#            1       0.92      1.00      0.96        35
#
#     accuracy                           0.95        65
#    macro avg       0.96      0.95      0.95        65
# weighted avg       0.96      0.95      0.95        65

# %% [markdown]
# ### Evaluasi Model dengan ROC AUC

# %%
# Menghitung ROC AUC Score
# Prediksi probabilitas untuk kelas positif (label 1)
predicted_probs = model_3.predict(test_data, verbose=1)

# Menggunakan label biner untuk ROC AUC
# Jika dataset adalah binary, kita cukup menggunakan predicted_probs untuk kelas 1
roc_auc = roc_auc_score(true_labels, predicted_probs)

print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 582ms/step
# ROC AUC Score: 0.9895

# %% [markdown]
# ### Plot Kurva ROC

# %%
# Menghitung ROC curve
fpr, tpr, thresholds = roc_curve(true_labels, predicted_probs)

# Visualisasi ROC curve
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Line diagonal
plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
# Menampilkan hasil prediksi dan label aktual
print("\nPredictions vs Actual Labels:")
for i in range(len(test_data.filepaths)):
    actual_label = test_data.classes[i]  # Label asli
    predicted_label = predicted_labels[i][0]  # Prediksi model
    print(f"File: {test_data.filepaths[i]} | Predicted: {predicted_label} | Actual: {actual_label}")

# Mapping numerik ke nama kelas
class_indices = {v: k for k, v in test_data.class_indices.items()}
print("\nClass Mapping:", class_indices)
# Out:
# Predictions vs Actual Labels:
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(10).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(104).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(121).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(125).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(134).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(142).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(145).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(146).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(155).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(156).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(158).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(17).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(170).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(171).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(185).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(186).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(191).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(199).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(22).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(27).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(29).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(31).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(45).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(46).jpg | Predicted: 1 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(51).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(53).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(60).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(67).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(89).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/abnormal/HB(9).jpg | Predicted: 0 | Actual: 0
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(106).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(107).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(110).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(12).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(130).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(131).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(138).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(139).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(140).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(150).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(154).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(162).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(170).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(173).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(179).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(192).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(196).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(20).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(201).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(203).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(207).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(219).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(221).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(223).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(30).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(33).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(36).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(44).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(50).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(53).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(59).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(61).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(63).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(89).jpg | Predicted: 1 | Actual: 1
# File: /content/drive/MyDrive/dataset_tubes_split/test/normal/Normal(91).jpg | Predicted: 1 | Actual: 1
#
# Class Mapping: {0: 'abnormal', 1: 'normal'}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Mapping numerik ke nama kelas
class_indices = {v: k for k, v in test_data.class_indices.items()}

# List untuk menyimpan indeks gambar berdasarkan kelas
normal_indices = []
abnormal_indices = []

# Cari indeks untuk kelas normal dan abnormal
for i in range(len(test_data.filepaths)):
    actual_label = test_data.classes[i]  # Ambil label aktual
    if class_indices[actual_label] == "normal":
        normal_indices.append(i)
    elif class_indices[actual_label] == "abnormal":
        abnormal_indices.append(i)

# Ambil 5 indeks pertama dari masing-masing kelas
num_samples = 5
selected_indices = normal_indices[:num_samples] + abnormal_indices[:num_samples]

# Plot gambar
fig, axes = plt.subplots(2, num_samples, figsize=(15, 6))  # 2 baris, 5 kolom
fig.suptitle("Normal and Abnormal Samples", fontsize=16)

for i, ax in enumerate(axes.flat):
    if i >= len(selected_indices):
        break

    index = selected_indices[i]
    filepath = test_data.filepaths[index]
    actual_label = class_indices[test_data.classes[index]]
    predicted_label = class_indices[predicted_labels[index][0]]

    # Load gambar
    img = plt.imread(filepath)

    # Tampilkan gambar di subplot
    ax.imshow(img)
    ax.axis('off')

    # Tampilkan prediksi dan label aktual
    ax.set_title(
        f"Predicted: {predicted_label}\nActual: {actual_label}",
        fontsize=10
    )

plt.tight_layout(rect=[0, 0, 1, 0.9])  # Tambahkan ruang untuk judul
plt.show()
